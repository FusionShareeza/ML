# %%
TYPE = 'GPU'

if TYPE == 'CPU':
    import numpy as np
else:
    import cupy as np
    
import scipy.special
import math
import matplotlib
from ray import tune
from csv import writer

# %%
training_data_file = open("./MNISTData_red/mnist_train_red_8_9_by_90P.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

test_data_file = open("./mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()


inputnodes = 784
outputnodes = 10
hiddennodes = 0
learning_rate = 0
epochs = 0


#hiddennodes_start = 100
#hiddennodes_stop = 1500
#hiddennodes_step = 100

#learningrate_start = 0.01
#learningrate_stop = 0.1
#learningrate_step = 0.01

#epochs_start = 2
#epochs_stop = 30
#epochs_step = 2

hiddennodes_start = 300
hiddennodes_stop = 1200
hiddennodes_step = 100

learningrate_start = 0.01
learningrate_stop = 0.1
learningrate_step = 0.01

epochs_start = 19
epochs_stop = 30
epochs_step = 4

# %%
class neuralNetwork:
    def __init__(self, innodes, outnodes, hidnodes, learningrate, epochs):
        self.inodes = innodes
        self.onodes = outnodes
        self.hnodes = hidnodes
        self.lr = learningrate
        self.epo = epochs;

        self.wih = ((np.random.rand(self.hnodes,self.inodes)*2)-1)
        self.who = ((np.random.rand(self.onodes,self.hnodes)*2)-1)

        #self.wih = (numy.random.normal(mu, sigma, ))
        
        #self.activation_function = lambda x: scipy.special.expit(x)
        
    def activation_function(self, z):
        return 1/(1+ np.exp(-z))

        pass

    def train(self, inputs_list, targets_list):
        inputs = np.array(inputs_list, ndmin=2).T
        targets = np.array(targets_list, ndmin=2).T

        hidden_inputs = np.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)

        final_inputs = np.dot(self.who, hidden_outputs)

        final_outputs = self.activation_function(final_inputs)
        
        output_errors = targets - final_outputs
        hidden_errors = np.dot(self.who.T, output_errors) 
        self.who += self.lr * np.dot( (output_errors*final_outputs*(1.0-final_outputs)), np.transpose(hidden_outputs)) 
        self.wih += self.lr * np.dot( (hidden_errors*hidden_outputs*(1.0-hidden_outputs)), np.transpose(inputs)) 
        
        pass

    def query(self, input_list):
        inputs = np.array(input_list, ndmin=2).T
        
        hidden_inputs = np.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        final_inputs = np.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs
    
    
    def test_train(self):  
        for e in range(self.epo):
            for record in training_data_list:

                all_values = record.split(',')

                inputs = (np.asarray(all_values[1:], dtype=np.float64) / 255.0 * 0.99) + 0.01

                targets = np.zeros(outputnodes) + 0.01
                targets[int(all_values[0])] = 0.99
                self.train(inputs, targets)
                pass
            pass

        scorecard = []

        for record in test_data_list:
            all_values = record.split(',')
            correct_label = int(all_values[0])
            inputs = (np.asarray(all_values[1:], dtype=np.float64) / 255.0 * 0.99) + 0.01
            outputs = self.query(inputs)
            label = np.argmax(outputs)
            if (label == correct_label):

                scorecard.append(1)
            else:

                scorecard.append(0)
                pass

            pass

            scorecard_array = np.asarray(scorecard)
            performance = scorecard_array.sum() / scorecard_array.size


        return performance

# %%
def append_list_as_row(list_of_elem):
    with open('Results.csv', 'a+', newline='') as write_obj:
        csv_writer = writer(write_obj)
        csv_writer.writerow(list_of_elem)

# %%
learningrate_i = learningrate_start
hiddennodes_i = hiddennodes_start
epochs_i = epochs_start


while epochs_i <= epochs_stop:
    while hiddennodes_i <= hiddennodes_stop:
        while learningrate_i <= learningrate_stop:
            intermediate_score = neuralNetwork(784,10,hiddennodes_i,learningrate_i,epochs_i).test_train()
            print('Epoch [{:02d}/{:02d}]     | Hidden_Nodes [{:04d}/{:04d}]     | Learning_Rate [{:.2f}/{:.2f}]     | Performance: {:.5f}'.format(epochs_i,epochs_stop,hiddennodes_i,hiddennodes_stop,learningrate_i,learningrate_stop,intermediate_score))
            append_list_as_row([784,10,hiddennodes_i,learningrate_i,epochs_i,intermediate_score])
            learningrate_i += learningrate_step 
        learningrate_i = learningrate_start    
        hiddennodes_i += hiddennodes_step
        print("========================================================")
    hiddennodes_i += hiddennodes_start
    epochs_i += epochs_step
    print("========================================================")
# Out:
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93580
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.93810
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94070
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.94460
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.93350
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.94330
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.94110
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.94320
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.94320
# Epoch [19/30]     | Hidden_Nodes [0300/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.93680
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93420
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.93940
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94770
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.93990
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.94330
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.94290
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.94280
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.94490
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.93550
# Epoch [19/30]     | Hidden_Nodes [0400/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.93700
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93630
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.94120
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94100
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.94130
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.94640
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.94310
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.94080
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.93390
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.94830
# Epoch [19/30]     | Hidden_Nodes [0500/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.93610
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93240
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.94650
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94380
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.95070
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.94020
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.93670
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.94000
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.93710
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.93580
# Epoch [19/30]     | Hidden_Nodes [0600/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.94340
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93820
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.94010
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94350
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.94810
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.94530
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.93720
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.93960
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.94890
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.94660
# Epoch [19/30]     | Hidden_Nodes [0700/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.94640
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93340
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.94090
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94250
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.94150
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.95020
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.93810
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.94040
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.94050
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.94840
# Epoch [19/30]     | Hidden_Nodes [0800/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.94150
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.94420
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.02/0.10]     | Performance: 0.94350
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.03/0.10]     | Performance: 0.94220
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.04/0.10]     | Performance: 0.94560
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.05/0.10]     | Performance: 0.94770
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.06/0.10]     | Performance: 0.94330
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.07/0.10]     | Performance: 0.94180
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.08/0.10]     | Performance: 0.94180
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.09/0.10]     | Performance: 0.93870
# Epoch [19/30]     | Hidden_Nodes [0900/1200]     | Learning_Rate [0.10/0.10]     | Performance: 0.94730
# ========================================================
# Epoch [19/30]     | Hidden_Nodes [1000/1200]     | Learning_Rate [0.01/0.10]     | Performance: 0.93540
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-075e7ca13ce3> in <module>
#       7     while hiddennodes_i <= hiddennodes_stop:
#       8         while learningrate_i <= learningrate_stop:
# ----> 9             intermediate_score = neuralNetwork(784,10,hiddennodes_i,learningrate_i,epochs_i).test_train()
#      10             print('Epoch [{:02d}/{:02d}]     | Hidden_Nodes [{:04d}/{:04d}]     | Learning_Rate [{:.2f}/{:.2f}]     | Performance: {:.5f}'.format(epochs_i,epochs_stop,hiddennodes_i,hiddennodes_stop,learningrate_i,learningrate_stop,intermediate_score))
#      11             append_list_as_row([784,10,hiddennodes_i,learningrate_i,epochs_i,intermediate_score])
#
# <ipython-input-3-e7b5561e4260> in test_train(self)
#      58                 targets = np.zeros(outputnodes) + 0.01
#      59                 targets[int(all_values[0])] = 0.99
# ---> 60                 self.train(inputs, targets)
#      61                 pass
#      62             pass
#
# <ipython-input-3-e7b5561e4260> in train(self, inputs_list, targets_list)
#      26         hidden_outputs = self.activation_function(hidden_inputs)
#      27
# ---> 28         final_inputs = np.dot(self.who, hidden_outputs)
#      29
#      30         final_outputs = self.activation_function(final_inputs)
#
# ~/.local/lib/python3.9/site-packages/cupy/linalg/_product.py in dot(a, b, out)
#      63     """
#      64     # TODO(okuta): check type
# ---> 65     return a.dot(b, out)
#      66
#      67
#
# KeyboardInterrupt:
